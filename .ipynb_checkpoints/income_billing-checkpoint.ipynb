# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Files & Create DF

# %%
brands_file = 'data/brand_lines.xlsx'
market_system_file = 'data/market_system.xlsx'
market_trip_file = 'data/market_trip.xlsx'
raw_data_file = 'data/raw_data.xlsx'
brands_df = pd.read_excel(brands_file)
market_system_df = pd.read_excel(market_system_file)
market_trip_df = pd.read_excel(market_trip_file)
raw_data_df = pd.read_excel(raw_data_file)

# %% [markdown]
# # Brands

# %% [markdown]
# ### Remove Unnamed Columns

# %%
for col in brands_df.columns:
    if 'Unnamed' in col:
        del brands_df[col]

# %% [markdown]
# ### Melt Columns

# %%
brands_df = pd.melt(brands_df)
brands_group = brands_df.groupby(['variable', 'value']).count().reset_index()

# %%
brands_group = brands_group[brands_group['value'] != 'Total Lines']

# %%
brands_group.head()
# Out:
#                variable                              value
# 0  58 Degrees & Holding      Big Stump Brew Co Lions Crown
# 1  58 Degrees & Holding  Big Stump Brewing Rowan's Red Ale
# 2  58 Degrees & Holding              Matua Sauvignon Blanc
# 3  58 Degrees & Holding      Powder Keg Cabernet Sauvignon
# 5  58 Degrees & Holding            Two Rivers Ginger Cider

# %% [markdown]
# # Market System Builder

# %% [markdown]
# Market System Builder Represents what's currently in the market. It needs to be audited before billing the distributors.
# Historical reports (brands by distributor, raw data reports, and market trip reports) are compared against the a market system builder to find red flags.

# %%
market_system_df.head()
# Out:
#             distributor  serviceable  distactive    locid        city  \
# 0  58 Degrees & Holding         True        True  1027267  Sacramento
# 1  58 Degrees & Holding         True        True  1027267  Sacramento
# 2  58 Degrees & Holding         True        True  1027267  Sacramento
# 3  58 Degrees & Holding         True        True  1027267  Sacramento
# 4  58 Degrees & Holding         True        True  1027267  Sacramento
#
#            address1    zip                            tapname      bid  \
# 0  1217 18th Street  95811                 Amador Brewing Ipa  1037280
# 1  1217 18th Street  95811              Amador Brewing Kolsch  1057032
# 2  1217 18th Street  95811  Big Stump Brewing Rowan's Red Ale  1209098
# 3  1217 18th Street  95811            Fort Rock Foggy Goggles  1092374
# 4  1217 18th Street  95811              Matua Sauvignon Blanc  1153068
#
#   zonevalue  area      did                                      client  \
# 0      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
# 1      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
# 2      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
# 3      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
# 4      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
#
#    clientNumber                                   recurDescription  quantity
# 0           NaN  Clean and bill all IND lines to acct\nback doo...         1
# 1           NaN  Clean and bill all IND lines to acct\nback doo...         1
# 2           NaN  Clean and bill all IND lines to acct\nback doo...         1
# 3           NaN  Clean and bill all IND lines to acct\nback doo...         1
# 4           NaN  Clean and bill all IND lines to acct\nback doo...         1

# %% [markdown]
# # FLAGS 1 & 2
#
# ### Check if Tap is Associated with Distributor
#
# * Throw flag if the tap is not associated with distributor in Brand Lines by Dist Report
# * If tap is not associated with distributor, check if the brewery is associated with distributor
#
#
# Checking if the tap's brewery is associated with the distributor eliminates hundreds of taps from a manual audit. We assume that if the distributor is associated with other taps from that brewery, it should also be associated with the new tap.

# %%
## Iterrate through every row of market_system
for index, row in market_system_df.iterrows():
    
    tap = row['tapname']
    dist = row['distributor']
    
    ## Create Data Frames for market system, brands, and raw data that only include the row's distributor
    market_system_audit = market_system_df[market_system_df['distributor'] == dist]
    brand_audit = brands_group[brands_group['variable'] == dist]
    brewery_audit = raw_data_df[raw_data_df['Distributor'] == dist]
    
    ## List of unique taps that have historically been associated with distributor
    brand_taps = brand_audit['value'].unique()
    
    ## List of unique breweries that have historically been associated with the distributor
    breweries = brewery_audit['BreweryName'].unique()
    
    ## Empty list that will store a certain portion of a breweries name.
    ## Used to check if the tap has a breweries name in it.
    brewery_names = []
    
    ## 1. Loop through breweries associated with distributor
    ## 2. Grab the first word in the brewery's name and add it to the brewery_names list
    for brewery in breweries:
        if not isinstance(brewery, float):
            name = brewery.split()
        
            if len(name[0]) > 3:
                brewery_names.append(name[0])
                
    ## 1. Check if the current row tap is associated with the distributor
    ## 2. If it's not, flag the row
    
    if tap not in brand_taps:
        market_system_df.loc[index, 'dist_tap_audit'] = 'x'
        
    ## 3. If the tap is flagged, check to see if the brewery name appears in the tap's name.
    ## 4. If it does, flag the row
       
        if any(x in tap for x in brewery_names):
            market_system_df.loc[index, 'brewery_dist_audit'] = 'x'
            
    ## THE SECOND FLAG IS A GOOD FLAG
    ## It means that the brewery is associated with the distributor, and we probably bill for it.
    ## Any flags in the 'dist_tap_audit' column that do not have 'brewery_dist_audit' flagged as well, 
    ### will need to be manually audited

# %% [markdown]
# #### brewery_name
#
# The brewery_names list only stores the first part of the breweries name as long as the length of that string is greater than 3.

# %%
brewery_names
# Out:
# ['Camelot', 'Line', 'Angeline', 'Craft', 'Girls']

# %% [markdown]
# ## Tap Audit Results

# %%
market_system_df[['dist_tap_audit','brewery_dist_audit']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19145 entries, 0 to 19144
# Data columns (total 2 columns):
# dist_tap_audit        562 non-null object
# brewery_dist_audit    353 non-null object
# dtypes: object(2)
# memory usage: 299.3+ KB

# %%
tap_audit = market_system_df[['distributor', 'client', 'tapname', 'dist_tap_audit', 'brewery_dist_audit']]
tap_audit = tap_audit[(tap_audit['dist_tap_audit'] == 'x') | (tap_audit['brewery_dist_audit'] == 'x')]
tap_audit.head()
# Out:
#               distributor                                      client  \
# 0    58 Degrees & Holding  58 Degrees & Holding Co. (Sacramento/18th)
# 1    58 Degrees & Holding  58 Degrees & Holding Co. (Sacramento/18th)
# 3    58 Degrees & Holding  58 Degrees & Holding Co. (Sacramento/18th)
# 19    ALTAMONT BEER WORKS             2M - Aptos St BBQ (Aptos/Aptos)
# 124   ALTAMONT BEER WORKS          Catos Ale House (Oakland/Piedmont)
#
#                              tapname dist_tap_audit brewery_dist_audit
# 0                 Amador Brewing Ipa              x                NaN
# 1              Amador Brewing Kolsch              x                NaN
# 3            Fort Rock Foggy Goggles              x                NaN
# 19   Altamont Beer Works Vasco Juice              x                  x
# 124       Altamont Beer Works L Town              x                  x

# %% [markdown]
# #### Total Taps to Audit:

# %%
total_tap_audit = tap_audit[tap_audit['brewery_dist_audit'] != 'x'].count()['tapname']

print(f'{total_tap_audit} total taps to audit.')
# Out:
# 209 total taps to audit.

# %%
market_system_df.head()
# Out:
#             distributor  serviceable  distactive    locid        city  \
# 0  58 Degrees & Holding         True        True  1027267  Sacramento
# 1  58 Degrees & Holding         True        True  1027267  Sacramento
# 2  58 Degrees & Holding         True        True  1027267  Sacramento
# 3  58 Degrees & Holding         True        True  1027267  Sacramento
# 4  58 Degrees & Holding         True        True  1027267  Sacramento
#
#            address1    zip                            tapname      bid  \
# 0  1217 18th Street  95811                 Amador Brewing Ipa  1037280
# 1  1217 18th Street  95811              Amador Brewing Kolsch  1057032
# 2  1217 18th Street  95811  Big Stump Brewing Rowan's Red Ale  1209098
# 3  1217 18th Street  95811            Fort Rock Foggy Goggles  1092374
# 4  1217 18th Street  95811              Matua Sauvignon Blanc  1153068
#
#   zonevalue  area      did                                      client  \
# 0      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
# 1      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
# 2      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
# 3      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
# 4      CA05   NaN  1002166  58 Degrees & Holding Co. (Sacramento/18th)
#
#    clientNumber                                   recurDescription  quantity  \
# 0           NaN  Clean and bill all IND lines to acct\nback doo...         1
# 1           NaN  Clean and bill all IND lines to acct\nback doo...         1
# 2           NaN  Clean and bill all IND lines to acct\nback doo...         1
# 3           NaN  Clean and bill all IND lines to acct\nback doo...         1
# 4           NaN  Clean and bill all IND lines to acct\nback doo...         1
#
#   dist_tap_audit brewery_dist_audit
# 0              x                NaN
# 1              x                NaN
# 2            NaN                NaN
# 3              x                NaN
# 4            NaN                NaN

# %% [markdown]
# # FLAGS 3 & 4
#
# ### Check if CA01 / CA04 accounts are zoned correctly
#
# * Import geojson polygon of zones CA01 and CA04
# * Check if zone CA01's account coordinates lie within the polygon of CA04
# * Check if zone CA04's account coordinates lie within the polygon of CA01
# * If the account's coordinates lie within incorrect polygon, flag the account.
#
#
# Zone CA01 and CA04 are both in San Jose and are divided by I-880. New accounts are often zoned incorrectly and billed to incorrect distributors. By checking against a polygonal representation of the zone, we can progmatically flag accounts that are zoned incorrectly.

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from geopandas.geoseries import *
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (20,10)

# %%
ca04_poly = gpd.read_file('data/ca04.geojson')
ca01_poly = gpd.read_file('data/ca01.geojson')

# %%
ax1 = ca04_poly.plot(color='purple', edgecolor = 'k', linewidth = 2, alpha=0.2)
ax2 = ca04_poly.plot(color='None', edgecolor = 'k', linewidth = 2, ax=ax1)
ax3 = ca01_poly.plot(color='pink', edgecolor = 'k', linewidth = 2, ax=ax1, alpha =0.2)
ax4 = ca01_poly.plot(color='None', edgecolor = 'k', linewidth = 2, ax=ax1)

# %%
locations = pd.read_excel('data/BAY_Send_Orders.xlsx')

# %%
ca04 = locations[locations[' Service Location - Contact - First Name'] == 'CA04']  
ca01 = locations[locations[' Service Location - Contact - First Name'] == 'CA01']

# %%
ca04 = ca04[[' Service Location - Description',' Latitude', ' Longitude']]
ca01 = ca01[[' Service Location - Description',' Latitude', ' Longitude']]

# %%
ax1 = ca04_poly.plot(color='None', edgecolor = 'k', linewidth = 2, label="Zone CA04 Shape")
ax2 = ca01_poly.plot(color='None', edgecolor = 'k', linewidth = 2, ax=ax1)
ax3 = ca04.plot(kind='scatter', x=' Longitude', y = ' Latitude', color = 'g', ax=ax1, label="Zone CA04 Account", alpha = 0.8)
ax4 = ca01.plot(kind='scatter', x=' Longitude', y = ' Latitude', color = 'b', ax=ax1, label ="Zone CA01 Account", alpha = 0.8)
plt.savefig('CA04-CA01 Zone Errors')

# %%
polygon4 = pd.read_json('data/ca04.geojson')
polygon4 = np.array(polygon4['features'][0]['geometry']['coordinates'][0])

polygon1 = pd.read_json('data/ca01.geojson')
polygon1 = np.array(polygon1['features'][0]['geometry']['coordinates'][0])

# %%
poly4 = Polygon(polygon4)
poly1 = Polygon(polygon1)

# %%
for index,row in ca01.iterrows():
    point = Point(row[' Longitude'], row[' Latitude'])
    if point.within(poly4):
        ca01.loc[index, 'ca01_audit'] = 'x'

for index,row in ca04.iterrows():
    point = Point(row[' Longitude'], row[' Latitude'])
    if point.within(poly1):
        ca04.loc[index, 'ca04_audit'] = 'x'

# %%
ca01errors = ca01[ca01['ca01_audit'] == 'x']
ca01errors = ca01errors[[' Service Location - Description', 'ca01_audit']]
ca01errors.rename(columns = {' Service Location - Description':'client'}, inplace = True) 
ca01errors.drop_duplicates(inplace=True)

# %%
ca04errors = ca04[ca04['ca04_audit'] == 'x']
ca04errors = ca04errors[[' Service Location - Description', 'ca04_audit']]
ca04errors.rename(columns = {' Service Location - Description':'client'}, inplace = True) 
ca04errors.drop_duplicates(inplace=True)

# %%
market_system_df = pd.merge(market_system_df, ca01errors, how='left', on='client')
market_system_df = pd.merge(market_system_df, ca04errors, how='left', on='client')

# %%
market_system_df[(market_system_df['ca01_audit'] == 'x') | (market_system_df['ca04_audit'] == 'x')]
# Out:
#                     distributor  serviceable  distactive    locid       city  \
# 142         ALTAMONT BEER WORKS         True        True  1109659   San Jose
# 8709   GOLDEN BRANDS - SAN JOSE         True        True  1112407   Campbell
# 8710   GOLDEN BRANDS - SAN JOSE         True        True  1112407   Campbell
# 8711   GOLDEN BRANDS - SAN JOSE         True        True  1112407   Campbell
# 8712   GOLDEN BRANDS - SAN JOSE         True        True  1112407   Campbell
# 9320   GOLDEN BRANDS - SAN JOSE         True        True  1059885   San Jose
# 9321   GOLDEN BRANDS - SAN JOSE         True        True  1059885   San Jose
# 9322   GOLDEN BRANDS - SAN JOSE         True        True  1059885   San Jose
# 9323   GOLDEN BRANDS - SAN JOSE         True        True  1059885   San Jose
# 9324   GOLDEN BRANDS - SAN JOSE         True        True  1059885   San Jose
# 9325   GOLDEN BRANDS - SAN JOSE         True        True  1059885   San Jose
# 9451   GOLDEN BRANDS - SAN JOSE         True        True     2288   San Jose
# 9452   GOLDEN BRANDS - SAN JOSE         True        True     2288   San Jose
# 9453   GOLDEN BRANDS - SAN JOSE         True        True     2288   San Jose
# 9454   GOLDEN BRANDS - SAN JOSE         True        True     2288   San Jose
# 9695   GOLDEN BRANDS - SAN JOSE         True        True  1055313   San Jose
# 9696   GOLDEN BRANDS - SAN JOSE         True        True  1055313   San Jose
# 9697   GOLDEN BRANDS - SAN JOSE         True        True  1055313   San Jose
# 9698   GOLDEN BRANDS - SAN JOSE         True        True  1055313   San Jose
# 9699   GOLDEN BRANDS - SAN JOSE         True        True  1055313   San Jose
# 9925   GOLDEN BRANDS - SAN JOSE         True        True  1109659   San Jose
# 9926   GOLDEN BRANDS - SAN JOSE         True        True  1109659   San Jose
# 9980   GOLDEN BRANDS - SAN JOSE         True        True     4704   San Jose
# 9981   GOLDEN BRANDS - SAN JOSE         True        True     4704   San Jose
# 16922       SAPPORO U.S.A. INC.         True        True  1087792  Palo Alto
# 16952       SAPPORO U.S.A. INC.         True        True  1016829   San Jose
# 18138            WINE WAREHOUSE         True        True  1087792  Palo Alto
# 18342            WINE WAREHOUSE         True        True  1059885   San Jose
# 18343            WINE WAREHOUSE         True        True  1059885   San Jose
# 18344            WINE WAREHOUSE         True        True  1059885   San Jose
# 18345            WINE WAREHOUSE         True        True  1059885   San Jose
# 18346            WINE WAREHOUSE         True        True  1059885   San Jose
# 18480            WINE WAREHOUSE         True        True  1109659   San Jose
# 18481            WINE WAREHOUSE         True        True  1109659   San Jose
# 18482            WINE WAREHOUSE         True        True  1109659   San Jose
# 18483            WINE WAREHOUSE         True        True  1109659   San Jose
#
#                             address1    zip  \
# 142                         78 S 1St  95113
# 8709              501 E Campbell Ave  95008
# 8710              501 E Campbell Ave  95008
# 8711              501 E Campbell Ave  95008
# 8712              501 E Campbell Ave  95008
# 9320        110 Paseo De San Antonio  95112
# 9321        110 Paseo De San Antonio  95112
# 9322        110 Paseo De San Antonio  95112
# 9323        110 Paseo De San Antonio  95112
# 9324        110 Paseo De San Antonio  95112
# 9325        110 Paseo De San Antonio  95112
# 9451              196 N Third Street  95131
# 9452              196 N Third Street  95131
# 9453              196 N Third Street  95131
# 9454              196 N Third Street  95131
# 9695   4035 Evergreen Village Ste 10  95135
# 9696   4035 Evergreen Village Ste 10  95135
# 9697   4035 Evergreen Village Ste 10  95135
# 9698   4035 Evergreen Village Ste 10  95135
# 9699   4035 Evergreen Village Ste 10  95135
# 9925                        78 S 1St  95113
# 9926                        78 S 1St  95113
# 9980                 956 Park Avenue  95126
# 9981                 956 Park Avenue  95126
# 16922      717 Stanford Shopping Ctr  94304
# 16952            86 South 1St Street  95113
# 18138      717 Stanford Shopping Ctr  94304
# 18342       110 Paseo De San Antonio  95112
# 18343       110 Paseo De San Antonio  95112
# 18344       110 Paseo De San Antonio  95112
# 18345       110 Paseo De San Antonio  95112
# 18346       110 Paseo De San Antonio  95112
# 18480                       78 S 1St  95113
# 18481                       78 S 1St  95113
# 18482                       78 S 1St  95113
# 18483                       78 S 1St  95113
#
#                                                  tapname      bid zonevalue  \
# 142                        Altamont Beer Works Scar City  1059374      CA04
# 8709                       Alaskan Brewing Alaskan Amber  1053917      CA01
# 8710                               Ballast Point Sculpin     2804      CA01
# 8711                             Blue Moon Belgian White  1054318      CA01
# 8712                                       Firestone 805     3752      CA01
# 9320                                       Firestone 805     3752      CA04
# 9321                   Lagunitas Born Yesterday Pale Ale  1055877      CA04
# 9322                                     Modelo Especial     3587      CA04
# 9323                                   Pabst Blue Ribbon    15575      CA04
# 9324                         Russian River Blind Pig IPA  1054710      CA04
# 9325                           Russian River STS Pilsner  1175979      CA04
# 9451                             Blue Moon Belgian White  1054318      CA01
# 9452                                         Coors Light    15465      CA01
# 9453                                       Firestone 805     3752      CA01
# 9454                                       Lagunitas Ipa  1053927      CA01
# 9695                             Blue Moon Belgian White  1054318      CA04
# 9696                        Deschutes Fresh Squeezed IPA  1054108      CA04
# 9697                                       Firestone 805     3752      CA04
# 9698                                      Lagunita's IPA    15557      CA04
# 9699                                New Belgium Fat Tire     2823      CA04
# 9925                             Russian River Blind Pig     4892      CA04
# 9926                    Russian River Pliney the Younger     5888      CA04
# 9980                             Blue Moon Belgium White     2796      CA04
# 9981                                      Lagunita's IPA    15557      CA04
# 16922                                            Sapporo  1052155      CA01
# 16952                                    Sapporo Premium    15540      CA04
# 18138                                Hitachino Nest Beer  1067065      CA01
# 18342                Anderson Valley Brewing Beerguy IPA  1136397      CA04
# 18343                             Coronado Orange Avenue     2692      CA04
# 18344                               North Coast Red Seal     3143      CA04
# 18345                                Paulaner Hefeweizen     2663      CA04
# 18346                                         Stem Cider  1065984      CA04
# 18480  North Coast Brewing Laguna Baja Mexican Style ...  1150667      CA04
# 18481                         Peregrine Ranch Chardonnay  1185242      CA04
# 18482                       Peregrine Ranch Old Vine Zin     8015      CA04
# 18483                  Port Brewing Santas Little Helper  1019929      CA04
#
#        area  did                                             client  \
# 142     NaN  157                       Pizza Flora (San Jose/S 1st)
# 8709    NaN   51                         Desi (Campbell/E Campbell)
# 8710    NaN   51                         Desi (Campbell/E Campbell)
# 8711    NaN   51                         Desi (Campbell/E Campbell)
# 8712    NaN   51                         Desi (Campbell/E Campbell)
# 9320    NaN   51        2M - Spread (San Jose/Paseo De San Antonio)
# 9321    NaN   51        2M - Spread (San Jose/Paseo De San Antonio)
# 9322    NaN   51        2M - Spread (San Jose/Paseo De San Antonio)
# 9323    NaN   51        2M - Spread (San Jose/Paseo De San Antonio)
# 9324    NaN   51        2M - Spread (San Jose/Paseo De San Antonio)
# 9325    NaN   51        2M - Spread (San Jose/Paseo De San Antonio)
# 9451    NaN   51         Corinthian Event Center (San Jose/N Third)
# 9452    NaN   51         Corinthian Event Center (San Jose/N Third)
# 9453    NaN   51         Corinthian Event Center (San Jose/N Third)
# 9454    NaN   51         Corinthian Event Center (San Jose/N Third)
# 9695    NaN   51             Curry Pizza House (San Jose/Evergreen)
# 9696    NaN   51             Curry Pizza House (San Jose/Evergreen)
# 9697    NaN   51             Curry Pizza House (San Jose/Evergreen)
# 9698    NaN   51             Curry Pizza House (San Jose/Evergreen)
# 9699    NaN   51             Curry Pizza House (San Jose/Evergreen)
# 9925    NaN   51                       Pizza Flora (San Jose/S 1st)
# 9926    NaN   51                       Pizza Flora (San Jose/S 1st)
# 9980    NaN   51                        Tonys Place (San Jose/Park)
# 9981    NaN   51                        Tonys Place (San Jose/Park)
# 16922   NaN  103  Taro San Japanese Noodle Bar (Palo Alto/Stanfo...
# 16952   NaN  103                         Ozu Sushi (San Jose/S 1st)
# 18138   NaN  121  Taro San Japanese Noodle Bar (Palo Alto/Stanfo...
# 18342   NaN  121        2M - Spread (San Jose/Paseo De San Antonio)
# 18343   NaN  121        2M - Spread (San Jose/Paseo De San Antonio)
# 18344   NaN  121        2M - Spread (San Jose/Paseo De San Antonio)
# 18345   NaN  121        2M - Spread (San Jose/Paseo De San Antonio)
# 18346   NaN  121        2M - Spread (San Jose/Paseo De San Antonio)
# 18480   NaN  121                       Pizza Flora (San Jose/S 1st)
# 18481   NaN  121                       Pizza Flora (San Jose/S 1st)
# 18482   NaN  121                       Pizza Flora (San Jose/S 1st)
# 18483   NaN  121                       Pizza Flora (San Jose/S 1st)
#
#        clientNumber                                   recurDescription  \
# 142        358400.0                                                NaN
# 8709            NaN  Earliest access time is 10am OR 2:30-3pm \npho...
# 8710            NaN  Earliest access time is 10am OR 2:30-3pm \npho...
# 8711            NaN  Earliest access time is 10am OR 2:30-3pm \npho...
# 8712            NaN  Earliest access time is 10am OR 2:30-3pm \npho...
# 9320       356020.0                 sanjose@spreaddeli.com\nKey Access
# 9321       356020.0                 sanjose@spreaddeli.com\nKey Access
# 9322       356020.0                 sanjose@spreaddeli.com\nKey Access
# 9323       356020.0                 sanjose@spreaddeli.com\nKey Access
# 9324       356020.0                 sanjose@spreaddeli.com\nKey Access
# 9325       356020.0                 sanjose@spreaddeli.com\nKey Access
# 9451            NaN                                                NaN
# 9452            NaN                                                NaN
# 9453            NaN                                                NaN
# 9454            NaN                                                NaN
# 9695            NaN  access @10:30 mon-fri & 10am on Saturday use b...
# 9696            NaN  access @10:30 mon-fri & 10am on Saturday use b...
# 9697            NaN  access @10:30 mon-fri & 10am on Saturday use b...
# 9698            NaN  access @10:30 mon-fri & 10am on Saturday use b...
# 9699            NaN  access @10:30 mon-fri & 10am on Saturday use b...
# 9925       358400.0                                                NaN
# 9926       358400.0                                                NaN
# 9980            NaN                                    Access 9:30-2pm
# 9981            NaN                                    Access 9:30-2pm
# 16922      356884.0            Clean and bill Sapporo at this location
# 16952           NaN  Please collect email\n\nClean and bill Sapporo...
# 18138      356884.0            Clean and bill Sapporo at this location
# 18342      356020.0                 sanjose@spreaddeli.com\nKey Access
# 18343      356020.0                 sanjose@spreaddeli.com\nKey Access
# 18344      356020.0                 sanjose@spreaddeli.com\nKey Access
# 18345      356020.0                 sanjose@spreaddeli.com\nKey Access
# 18346      356020.0                 sanjose@spreaddeli.com\nKey Access
# 18480      358400.0                                                NaN
# 18481      358400.0                                                NaN
# 18482      358400.0                                                NaN
# 18483      358400.0                                                NaN
#
#        quantity dist_tap_audit brewery_dist_audit ca01_audit ca04_audit
# 142           1            NaN                NaN        NaN          x
# 8709          1            NaN                NaN          x        NaN
# 8710          1            NaN                NaN          x        NaN
# 8711          1            NaN                NaN          x        NaN
# 8712          1            NaN                NaN          x        NaN
# 9320          1            NaN                NaN        NaN          x
# 9321          1            NaN                NaN        NaN          x
# 9322          1            NaN                NaN        NaN          x
# 9323          1            NaN                NaN        NaN          x
# 9324          1            NaN                NaN        NaN          x
# 9325          1            NaN                NaN        NaN          x
# 9451          1            NaN                NaN          x        NaN
# 9452          1            NaN                NaN          x        NaN
# 9453          1            NaN                NaN          x        NaN
# 9454          1            NaN                NaN          x        NaN
# 9695          1            NaN                NaN        NaN          x
# 9696          1            NaN                NaN        NaN          x
# 9697          1            NaN                NaN        NaN          x
# 9698          1            NaN                NaN        NaN          x
# 9699          1            NaN                NaN        NaN          x
# 9925          1            NaN                NaN        NaN          x
# 9926          1              x                  x        NaN          x
# 9980          1            NaN                NaN        NaN          x
# 9981          1            NaN                NaN        NaN          x
# 16922         1            NaN                NaN          x        NaN
# 16952         1            NaN                NaN        NaN          x
# 18138         1            NaN                NaN          x        NaN
# 18342         1            NaN                NaN        NaN          x
# 18343         1            NaN                NaN        NaN          x
# 18344         1            NaN                NaN        NaN          x
# 18345         1            NaN                NaN        NaN          x
# 18346         1            NaN                NaN        NaN          x
# 18480         1            NaN                NaN        NaN          x
# 18481         1            NaN                NaN        NaN          x
# 18482         1            NaN                NaN        NaN          x
# 18483         1            NaN                NaN        NaN          x

# %%
ca04errors
# Out:
#                                                  client ca04_audit
# 405                    Koja Kitchen (San Jose/E Brokaw)          x
# 1884        2M - Spread (San Jose/Paseo De San Antonio)          x
# 2166       Tassos Restaurant & Bar (San Jose/Southwest)          x
# 2192                        Tonys Place (San Jose/Park)          x
# 2202               Milan Italiano (San Jose/San Felipe)          x
# 2208             Curry Pizza House (San Jose/Evergreen)          x
# 2379                         Ozu Sushi (San Jose/S 1st)          x
# 2416                Goku Korean BBQ (San Jose/Meridian)          x
# 2422                       Pizza Flora (San Jose/S 1st)          x
# 2464            2M - Growler USA (San Jose/The Alameda)          x
# 2580           Sidecar Modern Tavern (Los Gatos/E Main)          x
# 2665                    Jtown Pizza Co (San Jose/N 6th)          x
# 2679                      Cafe Stritch (San Jose/S 1st)          x
# 2683  SoFa Market - The Fountainhead Bar (San Jose/S...          x
# 2690                           Ludwigs (San Jose/N 2Nd)          x

# %%
ca01errors
# Out:
#                                                  client ca01_audit
# 1591                     Tam Tam (Palo Alto/University)          x
# 1904  Residence Inn - Gentry Bar & Eatery (Cupertino...          x
# 2106         Corinthian Event Center (San Jose/N Third)          x
# 2133           Burgerim (San Jose/El Paseo De Saratoga)          x
# 2162                  Bar Bay Grill (San Jose/Saratoga)          x
# 2258                      Villa Ragusa (Campbell/S 2nd)          x
# 2440  Taro San Japanese Noodle Bar (Palo Alto/Stanfo...          x
# 2475                   Octane (San Jose/Charcot Avenue)          x
# 2547  Le Bon Modern Vietnamese (Sunnyvale/Persian Dr...          x
# 2630                         Desi (Campbell/E Campbell)          x
