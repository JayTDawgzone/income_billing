# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ### Load Files & Create DF

# %%
brands_file = 'data/brand_lines.xlsx'
market_system_file = 'data/market_system.xlsx'
market_trip_file = 'data/market_trip.xlsx'
raw_data_file = 'data/raw_data.xlsx'
brands_df = pd.read_excel(brands_file)
market_system_df = pd.read_excel(market_system_file)
market_trip_df = pd.read_excel(market_trip_file)
raw_data_df = pd.read_excel(raw_data_file)

# %% [markdown]
# # Brands

# %% [markdown]
# ### Remove Unnamed Columns

# %%
for col in brands_df.columns:
    if 'Unnamed' in col:
        del brands_df[col]

# %% [markdown]
# ### Melt Columns

# %%
brands_df = pd.melt(brands_df)
brands_group = brands_df.groupby(['variable', 'value']).count().reset_index()

# %%
brands_group = brands_group[brands_group['value'] != 'Total Lines']

# %%
brands_group.head()
# Out:
#                variable                              value
# 0  58 Degrees & Holding      Big Stump Brew Co Lions Crown
# 1  58 Degrees & Holding  Big Stump Brewing Rowan's Red Ale
# 2  58 Degrees & Holding              Matua Sauvignon Blanc
# 3  58 Degrees & Holding      Powder Keg Cabernet Sauvignon
# 5  58 Degrees & Holding            Two Rivers Ginger Cider

# %% [markdown]
# # Market System Builder

# %% [markdown]
# Market System Builder Represents what's currently in the market. It needs to be audited before billing the distributors.
# Historical reports (brands by distributor, raw data reports, and market trip reports) are compared against the a market system builder to find red flags.

# %%
market_system_df.head()
# Out:
#             distributor  serviceable  distactive    locid        city  \
# 0  58 Degrees & Holding         True        True  1027267  Sacramento
# 1  58 Degrees & Holding         True        True  1027267  Sacramento
# 2  58 Degrees & Holding         True        True  1027267  Sacramento
# 3  58 Degrees & Holding         True        True  1027267  Sacramento
# 4  58 Degrees & Holding         True        True  1027267  Sacramento
#
#            address1    zip                            tapname      bid  \
# 0  1217 18th Street  95811                 Amador Brewing Ipa  1037280
# 1  1217 18th Street  95811              Amador Brewing Kolsch  1057032
# 2  1217 18th Street  95811  Big Stump Brewing Rowan's Red Ale  1209098
# 3  1217 18th Street  95811            Fort Rock Foggy Goggles  1092374
# 4  1217 18th Street  95811              Matua Sauvignon Blanc  1153068
#
#   zonevalue  area      did                                      client  \
# ...

# %% [markdown]
# # Is the tap associated with the distributor?
#
# * Throw flag if the tap is not associated with distributor in Brand Lines by Dist Report
# * If tap is not associated with distributor, check if the brewery is associated with distributor
#
#
# Checking if the tap's brewery is associated with the distributor eliminates hundreds of taps from a manual audit. We assume that if the distributor is associated with other taps from that brewery, it should also be associated with the new tap.

# %%
## Iterrate through every row of market_system
for index, row in tqdm(market_system_df.iterrows(), total=market_system_df.shape[0]):
    
    tap = row['tapname']
    dist = row['distributor']
    
    ## Create Data Frames for market system, brands, and raw data that only include the row's distributor
    market_system_audit = market_system_df[market_system_df['distributor'] == dist]
    brand_audit = brands_group[brands_group['variable'] == dist]
    brewery_audit = raw_data_df[raw_data_df['Distributor'] == dist]
    
    ## List of unique taps that have historically been associated with distributor
    brand_taps = brand_audit['value'].unique()
    
    ## List of unique breweries that have historically been associated with the distributor
    breweries = brewery_audit['BreweryName'].unique()
    
    ## Empty list that will store a certain portion of a breweries name.
    ## Used to check if the tap has a breweries name in it.
    brewery_names = []
    
    ## 1. Loop through breweries associated with distributor
    ## 2. Grab the first word in the brewery's name and add it to the brewery_names list
    for brewery in breweries:
        if not isinstance(brewery, float):
            name = brewery.split()
        
            if len(name[0]) > 3:
                brewery_names.append(name[0])
                
    ## 1. Check if the current row tap is associated with the distributor
    ## 2. If it's not, flag the row
    
    if tap not in brand_taps:
        market_system_df.loc[index, 'dist_tap_audit'] = 'x'
        
    ## 3. If the tap is flagged, check to see if the brewery name appears in the tap's name.
    ## 4. If it does, flag the row
       
        if any(x in tap for x in brewery_names):
            market_system_df.loc[index, 'brewery_dist_audit'] = 'x'
            
    ## THE SECOND FLAG IS A GOOD FLAG
    ## It means that the brewery is associated with the distributor, and we probably bill for it.
    ## Any flags in the 'dist_tap_audit' column that do not have 'brewery_dist_audit' flagged as well, 
    ### will need to be manually audited
# Out:
# 100%|██████████| 37303/37303 [06:28<00:00, 96.00it/s]

# %% [markdown]
# #### brewery_name
#
# The brewery_names list only stores the first part of the breweries name as long as the length of that string is greater than 3.

# %%
brewery_names
# Out:
# ['Camelot', 'Line', 'Angeline', 'Craft', 'Girls']

# %% [markdown]
# ## Tap Audit Results

# %%
market_system_df[['dist_tap_audit','brewery_dist_audit']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37303 entries, 0 to 37302
# Data columns (total 2 columns):
# dist_tap_audit        752 non-null object
# brewery_dist_audit    453 non-null object
# dtypes: object(2)
# memory usage: 583.0+ KB

# %%
tap_audit = market_system_df[['distributor', 'client', 'tapname', 'dist_tap_audit', 'brewery_dist_audit']]
tap_audit = tap_audit[(tap_audit['dist_tap_audit'] == 'x') | (tap_audit['brewery_dist_audit'] == 'x')]
tap_audit.head()
# Out:
#              distributor                                      client  \
# 0   58 Degrees & Holding  58 Degrees & Holding Co. (Sacramento/18th)
# 1   58 Degrees & Holding  58 Degrees & Holding Co. (Sacramento/18th)
# 3   58 Degrees & Holding  58 Degrees & Holding Co. (Sacramento/18th)
# 11   ALTAMONT BEER WORKS              Extreme Pizza (Alamo/Danville)
# 21   ALTAMONT BEER WORKS             2M - Aptos St BBQ (Aptos/Aptos)
#
#                             tapname dist_tap_audit brewery_dist_audit
# 0                Amador Brewing Ipa              x                NaN
# 1             Amador Brewing Kolsch              x                NaN
# 3           Fort Rock Foggy Goggles              x                NaN
# 11  Altamont Beer Works Vasco Juice              x                  x
# 21  Altamont Beer Works Vasco Juice              x                  x

# %% [markdown]
# #### Total Taps to Audit:

# %%
total_tap_audit = tap_audit[tap_audit['brewery_dist_audit'] != 'x'].count()['tapname']

print(f'{total_tap_audit} total taps to audit.')
# Out:
# 299 total taps to audit.

# %%
market_system_df.head()
# Out:
#             distributor  serviceable  distactive    locid        city  \
# 0  58 Degrees & Holding         True        True  1027267  Sacramento
# 1  58 Degrees & Holding         True        True  1027267  Sacramento
# 2  58 Degrees & Holding         True        True  1027267  Sacramento
# 3  58 Degrees & Holding         True        True  1027267  Sacramento
# 4  58 Degrees & Holding         True        True  1027267  Sacramento
#
#            address1    zip                            tapname      bid  \
# 0  1217 18th Street  95811                 Amador Brewing Ipa  1037280
# 1  1217 18th Street  95811              Amador Brewing Kolsch  1057032
# 2  1217 18th Street  95811  Big Stump Brewing Rowan's Red Ale  1209098
# 3  1217 18th Street  95811            Fort Rock Foggy Goggles  1092374
# 4  1217 18th Street  95811              Matua Sauvignon Blanc  1153068
#
#   zonevalue  area      did                                      client  \
# ...

# %% [markdown]
# # Check if CA01 / CA04 accounts are zoned correctly
#
# * Import geojson polygon of zones CA01 and CA04
# * Check if zone CA01's account coordinates lie within the polygon of CA04
# * Check if zone CA04's account coordinates lie within the polygon of CA01
# * If the account's coordinates lie within incorrect polygon, flag the account.
#
#
# Zone CA01 and CA04 are both in San Jose and are divided by I-880. New accounts are often zoned incorrectly and billed to incorrect distributors. By checking against a polygonal representation of the zone, we can progmatically flag accounts that are zoned incorrectly.

# %% [markdown]
# #### Import Files and Set Parameters

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from geopandas.geoseries import *
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (20,10)

# %%
ca04_poly = gpd.read_file('data/ca04.geojson')
ca01_poly = gpd.read_file('data/ca01.geojson')
locations = pd.read_excel('data/BAY_Send_Orders.xlsx')

# %% [markdown]
# ### San Jose Zone Polygons

# %%
ax1 = ca04_poly.plot(color='purple', edgecolor = 'k', linewidth = 1, alpha=0.2)
ax2 = ca04_poly.plot(color='None', edgecolor = 'k', linewidth = 1, ax=ax1)
ax3 = ca01_poly.plot(color='pink', edgecolor = 'k', linewidth = 1, ax=ax1, alpha =0.2)
ax4 = ca01_poly.plot(color='None', edgecolor = 'k', linewidth = 1, ax=ax1)

plt.title("Zone CA04 & CA01 Polygons")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.annotate("CA04", (-122.1,37.35))
plt.annotate("CA01", (-121.85,37.33))
# Out:
# Text(-121.85, 37.33, 'CA01')

# %% [markdown]
# #### Seperate Data from Zone CA01 & CA04

# %%
ca04 = locations[locations[' Service Location - Contact - First Name'] == 'CA04']  
ca01 = locations[locations[' Service Location - Contact - First Name'] == 'CA01']

# %%
ca04 = ca04[[' Service Location - Description',' Latitude', ' Longitude']]
ca01 = ca01[[' Service Location - Description',' Latitude', ' Longitude']]

# %% [markdown]
# ### Visualizing Zone Errors

# %%
ax1 = ca04_poly.plot(color='None', edgecolor = 'k', linewidth = 2, label="Zone CA04 Shape")
ax2 = ca01_poly.plot(color='None', edgecolor = 'k', linewidth = 2, ax=ax1)
ax3 = ca04.plot(kind='scatter', x=' Longitude', y = ' Latitude', color = 'g', ax=ax1, label="Zone CA04 Account", alpha = 0.8)
ax4 = ca01.plot(kind='scatter', x=' Longitude', y = ' Latitude', color = 'b', ax=ax1, label ="Zone CA01 Account", alpha = 0.8)
plt.annotate('Green Circles in CA01 = ERROR', (-122.2,36.95))
plt.annotate('Blue Circles in CA04 = ERROR', (-122.2,36.92))
plt.savefig('CA04-CA01 Zone Errors')

# %% [markdown]
# ## Flagging Zone Errors
#
#
# If a location's coordinate's lie within the incorrect zone, flag the account

# %%
polygon4 = pd.read_json('data/ca04.geojson')
polygon4 = np.array(polygon4['features'][0]['geometry']['coordinates'][0])
polygon1 = pd.read_json('data/ca01.geojson')
polygon1 = np.array(polygon1['features'][0]['geometry']['coordinates'][0])

# %%
poly4 = Polygon(polygon4)
poly1 = Polygon(polygon1)

# %%
for index,row in ca01.iterrows():
    point = Point(row[' Longitude'], row[' Latitude']) ### Coordinates must be turned into geopandas POINT
    if point.within(poly4):
        ca01.loc[index, 'ca01_audit'] = 'x'

for index,row in ca04.iterrows():
    point = Point(row[' Longitude'], row[' Latitude'])
    if point.within(poly1):
        ca04.loc[index, 'ca04_audit'] = 'x'

# %% [markdown]
# #### CA01 Errors

# %%
ca01errors = ca01[ca01['ca01_audit'] == 'x']
ca01errors = ca01errors[[' Service Location - Description', 'ca01_audit']]
ca01errors.rename(columns = {' Service Location - Description':'client'}, inplace = True) 
ca01errors.drop_duplicates(inplace=True)
ca01errors
# Out:
#                                                  client ca01_audit
# 1591                     Tam Tam (Palo Alto/University)          x
# 1904  Residence Inn - Gentry Bar & Eatery (Cupertino...          x
# 2106         Corinthian Event Center (San Jose/N Third)          x
# 2133           Burgerim (San Jose/El Paseo De Saratoga)          x
# 2162                  Bar Bay Grill (San Jose/Saratoga)          x
# 2258                      Villa Ragusa (Campbell/S 2nd)          x
# 2440  Taro San Japanese Noodle Bar (Palo Alto/Stanfo...          x
# 2475                   Octane (San Jose/Charcot Avenue)          x
# 2547  Le Bon Modern Vietnamese (Sunnyvale/Persian Dr...          x
# 2630                         Desi (Campbell/E Campbell)          x

# %% [markdown]
# #### CA04 Errors

# %%
ca04errors = ca04[ca04['ca04_audit'] == 'x']
ca04errors = ca04errors[[' Service Location - Description', 'ca04_audit']]
ca04errors.rename(columns = {' Service Location - Description':'client'}, inplace = True) 
ca04errors.drop_duplicates(inplace=True)
ca04errors
# Out:
#                                                  client ca04_audit
# 405                    Koja Kitchen (San Jose/E Brokaw)          x
# 1884        2M - Spread (San Jose/Paseo De San Antonio)          x
# 2166       Tassos Restaurant & Bar (San Jose/Southwest)          x
# 2192                        Tonys Place (San Jose/Park)          x
# 2202               Milan Italiano (San Jose/San Felipe)          x
# 2208             Curry Pizza House (San Jose/Evergreen)          x
# 2379                         Ozu Sushi (San Jose/S 1st)          x
# 2416                Goku Korean BBQ (San Jose/Meridian)          x
# 2422                       Pizza Flora (San Jose/S 1st)          x
# 2464            2M - Growler USA (San Jose/The Alameda)          x
# 2580           Sidecar Modern Tavern (Los Gatos/E Main)          x
# 2665                    Jtown Pizza Co (San Jose/N 6th)          x
# 2679                      Cafe Stritch (San Jose/S 1st)          x
# ...

# %% [markdown]
# #### Update the Market System Builder

# %%
market_system_df = pd.merge(market_system_df, ca01errors, how='left', on='client')
market_system_df = pd.merge(market_system_df, ca04errors, how='left', on='client')

# %%
market_system_df[(market_system_df['ca01_audit'] == 'x') | (market_system_df['ca04_audit'] == 'x')]
# Out:
#                distributor  serviceable  distactive    locid      city  \
# 243    ALTAMONT BEER WORKS         True        True    13479  San Jose
# 244    ALTAMONT BEER WORKS         True        True    13479  San Jose
# 248    ALTAMONT BEER WORKS         True        True  1109659  San Jose
# 249    ALTAMONT BEER WORKS         True        True  1102103  San Jose
# 250    ALTAMONT BEER WORKS         True        True  1102103  San Jose
# ...                    ...          ...         ...      ...       ...
# 35789       WINE WAREHOUSE         True        True  1102103  San Jose
# 35790       WINE WAREHOUSE         True        True  1102103  San Jose
# 35791       WINE WAREHOUSE         True        True  1102103  San Jose
# 35792       WINE WAREHOUSE         True        True  1102103  San Jose
# 35793       WINE WAREHOUSE         True        True  1102103  San Jose
#
#                       address1    zip                             tapname  \
# ...

# %% [markdown]
# # Exceptions
#
# These exceptions only affect certain distributors/taps/accounts.
#
# * **sierra_nevada_chico_audit** Sierra Nevada taps in Chico can only be associated with Sierra Nevada
# * **junction_audit** Livermore - "The Junction" is Territory CA01.
# * **bud_in_mountain_house** Do not service "Bud" products in Mountain House, CA.
# * **alvarado_zone_ca01** Only bill for Alvarado Street products in Morgan Hill, Zone CA01.
# * **ab_do_not_bill** In Zone CA04, do not bill certain products at certain accounts (the accounts buy these products from a store.)
# * **b_and_b_sacrament** Do not bill "Sacrament" taps at Burgers & Brewhouse.
# * **gb_do_not_bill** Golden Brands Products at Green River Brewing are not billable.
# * **ym_do_not_bill** Holiday Inn - Zone CA13 - Do not bill Young's Market products here.
# * **donaghy_do_not_bill** Do not bill amador taps to donaghy at certain accounts.
# * **wwh_do_not_bill** Do not bill Wine Warehouse for Lola Bistro and Express.
# * **valley_wide_mariposa** Bud, Coors and Truly are Valley Wide taps in the city of Mariposa.
# * **donaghy_dos_equis** Dos Equis - bill to Donaghy in city of Bear Valley and Fish Camp.
# * **markstein_galt** Modelo, Drakes, Russian River, Brooklyn, 21st Amendment, Fifty Fifty, Avery, Seismic, are billed to Markstein Sacto in city of Galt.
# * **bbd_miners_alley** Don't clean anything at Miner's Alley except for Miner's Alley brands - bill to miners alley.
# * **veranda_ym** Freak Show Cab, Ryder Chardonnay, Bonterra S/B, Angline Cab, A to Z Pinot, Liberty School Cab, St Francis OVZ are billed to Young's Market at Verdana Lux
# * **house_couch** House beer is billed to Couch at Monterey Penninsula Country Club.

# %% [markdown]
# #### Flag specific errors

# %%
alvarado_street_products = brands_group[brands_group['variable'] == 'ALVARADO STREET BREWING COMPANY']['value'].unique()
amador_dnb_accounts = [1043984,1043982,1043981,1076893,1077864,1043983,1043969,
                       1043971,1043972,1043974,1041917,1043978,1080915,1060561,]

for index, row in market_system_df.iterrows():
    
    ### SIERRA NEVADA TAPS IN CHICO
    if row['city'] != 'Chico':
        pass
    else:
        tap = row['tapname']
        if 'sierra' in tap.lower() :
            if row['distributor'] != 'SIERRA NEVADA':
                market_system_df.loc[index, 'sierra_nevada_chico_audit'] = 'x'
    
    ### THE JUNCTION
    if row['client'] == 'The Junction (Livermore/Mines)':
        if row['zonevalue'] != 'CA01':
            market_system_df.loc[index, 'junction_audit'] = 'x'
            
    ### BUD PRODUCT IN MOUNTAIN HOUSE
    if row['city'] == 'Mountain House':
        if 'bud' in row['tapname'].lower():
            market_system_df.loc[index, 'bud_in_mountain_house'] = 'x'
            
    ### ONLY BILL ALVARDO STREET PRODUCTS IN MORGAN HILL, ZONE CA01
    if row['zonevalue'] == 'CA01':
        if row['city'] != 'Morgan Hill':
            if 'alvarado' in row['tapname'].lower():
                if row['distributor'] == "ALVARADO STREET BREWING COMPANY":
                    market_system_df.loc[index, 'alvarado_zone_ca01'] = 'x'
            
    ## ZONE CA04 - DO NOT BILL ANHEUSER-BUSCH FOR CERTAIN PRODUCTS AT CERTAIN ACCOUNTS
    if row['locid'] == 11261: ### Pizza My Heart (San Jose/ Airport)
        if "bud" in row['tapname'].lower():
            if row['distributor'] == "ANHEUSER-BUSCH BAY AREA SALES":
                market_system_df.loc[index, 'ab_do_not_bill'] = 'x'
    
    if row['locid'] == 3531: ### New Ciceros Pizza (San Jose/Bollinger Rd)
        if "bud" in row['tapname'].lower() or 'stella' in row['tapname'].lower():
            if row['distributor'] == "ANHEUSER-BUSCH BAY AREA SALES":
                market_system_df.loc[index, 'ab_do_not_bill'] = 'x'
                    
    if row['locid'] == 3515: ### New Ciceros Pizza (San Jose/Bollinger Rd)
        if "kirin" in row['tapname'].lower():
            if row['distributor'] == "ANHEUSER-BUSCH BAY AREA SALES":
                market_system_df.loc[index, 'ab_do_not_bill'] = 'x'

    if row['locid'] == 2969: ### OOB - Kamza Sushi (Richmond/Pierce)
        if "kirin" in row['tapname'].lower():
            if row['distributor'] == "ANHEUSER-BUSCH BAY AREA SALES":
                market_system_df.loc[index, 'ab_do_not_bill'] = 'x'
                      
    if row['locid'] == 4581: ### The Bistro (Hayward/B)
        if "stella" in row['tapname'].lower():
            if row['distributor'] == "ANHEUSER-BUSCH BAY AREA SALES":
                market_system_df.loc[index, 'ab_do_not_bill'] = 'x'    

    if row['locid'] == 4580: ### The Bistro (Milpitas/Barber)
        if "stella" in row['tapname'].lower():
            if row['distributor'] == "ANHEUSER-BUSCH BAY AREA SALES":
                market_system_df.loc[index, 'ab_do_not_bill'] = 'x' 
    
    
    ### DO NOT BILL MUSSETTER FOR SACRAMENT TAPS AT BURGERS & BREWS
    if row['locid'] == 1983 or row['locid'] == 1017348 or row['locid'] == 1982 or row['locid'] == 1984 or row['locid'] == 1021588:
        if 'sacrament' in row['tapname'].lower():
            if row['distributor'] == "MUSSETTER":
                market_system_df.loc[index, 'b_and_b_sacrament'] = 'x' 
                
  
    ### DO NOT BILL GOLDEN BRANDS AT GREEN RIVER BREWING
    if row['locid'] == 2318:
        if 'golden brands' in row['distributor'].lower():
            market_system_df.loc[index, 'gb_do_not_bill'] = 'x' 
            

    ### HOLIDAY INN (San Francisco/Van Ness) - DO NOT BILL YOUNG'S MARKET
    if row['locid'] == 647:
        if row['distributor'] == 'YOUNG\'S MARKET COMPANY':
            market_system_df.loc[index, 'ym_do_not_bill'] = 'x' 
            
    ### DO NOT BILL AMADOR BREWING TO DONAGHY AT CERTAIN ACCOUNTS
    if row['locid'] in amador_dnb_accounts:
        if row['distributor'] == 'Donaghy':
            market_system_df.loc[index, 'donaghy_do_not_bill'] = 'x' 

    ### DO NOT BILL WWH AT LOLA BISTRO EXPRESS
    if row['locid'] == 1076934:
        if 'wine warehouse' in row['distributor'].lower():
            market_system_df.loc[index, 'wwh_do_not_bill'] = 'x'
            
    ### BUD, COORS AND TRULY ARE VALLEYWIDE IN CITY OF MARIPOSA
    if row['city'] == "Mariposa":
        if 'bud' in row['tapname'].lower():
            market_system_df.loc[index, 'valley_wide_mariposa'] = 'x'
        if 'coors' in row['tapname'].lower():
            market_system_df.loc[index, 'valley_wide_mariposa'] = 'x'
        if 'truly' in row['tapname'].lower():
            market_system_df.loc[index, 'valley_wide_mariposa'] = 'x'
    
    ### DOS EQUIS BILL TO DONAGHY IN BEAR VALLEY AND FISH CAMP
    if row['city'] == "Bear Valley" or row['city'] == "Fish Camp":
        if 'dos equis' in row['tapname']:
            market_system_df.loc[index, 'donaghy_dos_equis'] = 'x'
    
    ### MODELO, DRAKES, RUSSIAN RIVER, BROOKLYN, 21st AMENDMENT, FIFTY FIFTY, AVERY, SEISMIC 
    ### BILL TO MARKSTEIN SACTO IN GALT
    if row['city'] == "Galt":
        if 'modelo' in row['tapname'].lower():
            if row['distributor'] != 'MARKSTEIN BEVERAGE CO - SACTO':
                market_system_df.loc[index, 'markstein_galt'] = 'x'
        if 'drakes' in row['tapname'].lower():
            if row['distributor'] != 'MARKSTEIN BEVERAGE CO - SACTO':
                market_system_df.loc[index, 'markstein_galt'] = 'x'
        if 'russian river' in row['tapname'].lower():
            if row['distributor'] != 'MARKSTEIN BEVERAGE CO - SACTO':
                market_system_df.loc[index, 'markstein_galt'] = 'x'
        if 'brooklyn' in row['tapname'].lower():
            if row['distributor'] != 'MARKSTEIN BEVERAGE CO - SACTO':
                market_system_df.loc[index, 'markstein_galt'] = 'x'
        if '21st' in row['tapname'].lower():
            if row['distributor'] != 'MARKSTEIN BEVERAGE CO - SACTO':
                market_system_df.loc[index, 'markstein_galt'] = 'x'
        if 'fifty fifty' in row['tapname'].lower():
            if row['distributor'] != 'MARKSTEIN BEVERAGE CO - SACTO':
                market_system_df.loc[index, 'markstein_galt'] = 'x'
        if 'avery' in row['tapname'].lower():
            if row['distributor'] != 'MARKSTEIN BEVERAGE CO - SACTO':
                market_system_df.loc[index, 'markstein_galt'] = 'x'
        if 'seismic' in row['tapname'].lower():
            if row['distributor'] != 'MARKSTEIN BEVERAGE CO - SACTO':
                market_system_df.loc[index, 'markstein_galt'] = 'x'

    ### MINERS ALLEY - DO NOT BILL TO BRITISH BULL DOG, ONLY BILL MINER'S ALLEY FOR MINER'S ALLEY BRANDS
    if row['locid'] == 3363:
        if 'miner' in row['tapname'].lower():
            if row['distributor'] == 'BRITISH BULLDOG BREWERY':
                market_system_df.loc[index, 'bbd_miners_alley'] = 'x'

    ### VERANDA LUX - WINE LINES BILLED TO YOUNGS MARKET
    if row['locid'] == 1040937:
        if 'freak show cab' in row['tapname'].lower() and row['distributor'] != 'YOUNG\'S MARKET COMPANY':
            market_system_df.loc[index, 'veranda_ym'] = 'x'
        if 'ryder chard' in row['tapname'].lower() and row['distributor'] != 'YOUNG\'S MARKET COMPANY':
            market_system_df.loc[index, 'veranda_ym'] = 'x'
        if 'bonterra s' in row['tapname'].lower() and row['distributor'] != 'YOUNG\'S MARKET COMPANY':
            market_system_df.loc[index, 'veranda_ym'] = 'x'
        if 'angeline cab' in row['tapname'].lower() and row['distributor'] != 'YOUNG\'S MARKET COMPANY':
            market_system_df.loc[index, 'veranda_ym'] = 'x'
        if 'a to z' in row['tapname'].lower() and row['distributor'] != 'YOUNG\'S MARKET COMPANY':
            market_system_df.loc[index, 'veranda_ym'] = 'x'
        if 'liberty school cab' in row['tapname'].lower() and row['distributor'] != 'YOUNG\'S MARKET COMPANY':
            market_system_df.loc[index, 'veranda_ym'] = 'x'
        if 'st francis ovz' in row['tapname'].lower() and row['distributor'] != 'YOUNG\'S MARKET COMPANY':
            market_system_df.loc[index, 'veranda_ym'] = 'x'

    ### MONTEREY PENN. COUNTRY CLUB - HOUSE BEER BILLED TO COUCH
    if row['locid'] == 1141:
        if 'house' in row['tapname'].lower():
            if row['distributor'] != 'COUCH DISTRIBUTING':
                market_system_df.loc[index, 'house_couch'] = 'x'

# %%
market_system_df.head()
# Out:
#             distributor  serviceable  distactive    locid        city  \
# 0  58 Degrees & Holding         True        True  1027267  Sacramento
# 1  58 Degrees & Holding         True        True  1027267  Sacramento
# 2  58 Degrees & Holding         True        True  1027267  Sacramento
# 3  58 Degrees & Holding         True        True  1027267  Sacramento
# 4  58 Degrees & Holding         True        True  1027267  Sacramento
#
#            address1    zip                            tapname      bid  \
# 0  1217 18th Street  95811                 Amador Brewing Ipa  1037280
# 1  1217 18th Street  95811              Amador Brewing Kolsch  1057032
# 2  1217 18th Street  95811  Big Stump Brewing Rowan's Red Ale  1209098
# 3  1217 18th Street  95811            Fort Rock Foggy Goggles  1092374
# 4  1217 18th Street  95811              Matua Sauvignon Blanc  1153068
#
#   zonevalue  ...  dist_tap_audit  brewery_dist_audit ca01_audit  ca04_audit  \
# ...

# %%
try:
    count = market_system_df["sierra_nevada_chico_audit"].count()
    print(f'Sierra Nevada Taps in Chico not billed to Sierra Nevada: {count}')
except:
    print(f'Sierra Nevada Taps in Chico not billed to Sierra Nevada: 0')

try:
    count = market_system_df["bud_in_mountain_house"].count()
    print(f'Bud Products in Mountain House: {count}')
except:
    print(f'Bud Products in Mountain House: 0')

try:
    count = market_system_df["alvarado_zone_ca01"].count()
    print(f'Alvarado Street products billed in CA01 outside Morgan Hill: {count}')
except:
    print(f'Alvarado Street products billed in CA01 outside Morgan Hill: 0')

try:
    count = market_system_df["ab_do_not_bill"].count()
    print(f'Anheuser-Busch products billed to accounts marked DNB: {count}')
except:
    print(f'Anheuser-Busch products billed to accounts marked DNB: 0')

try:
    count = market_system_df["b_and_b_sacrament"].count()
    print(f'Sacrament Lines at Burgers & Brews billed to distributor: {count}')
except:
    print(f'Sacrament Lines at Burgers & Brews billed to distributor: 0')
    
try:
    count = market_system_df["gb_do_not_bill"].count()
    print(f'Golden Brands products billed to Green River Brewing: {count}')
except:
    print(f'Golden Brands products billed to Green River Brewing: 0')

try:
    count = market_system_df["ym_do_not_bill"].count()
    print(f'Young\'s Market products billed to accounts marked DNB: {count}')
except:
    print(f'Young\'s Market products billed to accounts marked DNB: 0')

try:
    count = market_system_df["donaghy_do_not_bill"].count()
    print(f'Amador Brewing products billed to Donaghy at accounts marked DNB: {count}')
except:
    print(f'Amador Brewing products billed to Donaghy at accounts marked DNB: 0')

try:
    count = market_system_df["wwh_do_not_bill"].count()
    print(f'WWH products billed to accounts marked DNB: {count}')
except:
    print(f'WWH products billed to accounts marked DNB: 0')

try:
    count = market_system_df["valley_wide_mariposa"].count()
    print(f'Bud, Coors, and Truly products not billed to Valley Wide in city of Mariposa: {count}')
except:
    print(f'Bud, Coors and, Truly products not billed to Valley Wide in city of Mariposa: 0')

try:
    count = market_system_df["donaghy_dos_equis"].count()
    print(f'Dos Equis taps not billed to Donaghy in Fish Camp or Bear Valley: {count}')
except:
    print(f'Dos Equis taps not billed to Donaghy in Fish Camp or Bear Valley: 0')

try:
    count = market_system_df["markstein_galt"].count()
    print(f'Markstein products not billed to Markstein in city of Galt: {count}')
except:
    print(f'Markstein products not billed to Markstein in city of Galt: 0')
try:
    count = market_system_df["bbd_miners_alley"].count()
    print(f'Miners Alley products billed to distributor at Miner\'s Alley: {count}')
except:
    print(f'Miners Alley products billed to distributor at Miner\'s Alley: 0')

try:
    count = market_system_df["veranda_ym"].count()
    print(f'Veranda Lux wine lines not billed to Young\'s Market: {count}')
except:
    print(f'Veranda Lux wine lines not billed to Young\'s Market: 0')

try:
    count = market_system_df["house_couch"].count()
    print(f'Monterey Penninsula Country Club "House" products not billed to Couch Distributing: {count}')
except:
    print(f'Monterey Penninsula Country Club "House" products not billed to Couch Distributing: 0')
# Out:
# Sierra Nevada Taps in Chico not billed to Sierra Nevada: 0
# Bud Products in Mountain House: 0
# Alvarado Street products billed in CA01 outside Morgan Hill: 0
# Anheuser-Busch products billed to accounts marked DNB: 1
# Sacrament Lines at Burgers & Brews billed to distributor: 22
# Golden Brands products billed to Green River Brewing: 0
# Young's Market products billed to accounts marked DNB: 0
# Amador Brewing products billed to Donaghy at accounts marked DNB: 10
# WWH products billed to accounts marked DNB: 0
# Bud, Coors, and Truly products not billed to Valley Wide in city of Mariposa: 14
# Dos Equis taps not billed to Donaghy in Fish Camp or Bear Valley: 0
# Markstein products not billed to Markstein in city of Galt: 2
# Miners Alley products billed to distributor at Miner's Alley: 0
# Veranda Lux wine lines not billed to Young's Market: 0

# %% [markdown]
# # New Accounts
#
# * Compare Market System Builder to Raw Data
# * If any Market System Builder Accounts do not exist in Raw Data, they are new.
#
#
# New accounts should be audited for manual entry errors upon entering the accounts, regardless if they threw another flag or not.

# %%
grouped_raw_data = raw_data_df.groupby(['LocationID', 'Location']).count().reset_index()
grouped_raw_data = raw_data_df.sort_values(by='LocationID')

# %% [markdown]
# #### Unique Raw Data Location IDs

# %%
unique_raw_data = grouped_raw_data['LocationID'].unique()

# %% [markdown]
# #### Flag if new account

# %%
for index,row in market_system_df.iterrows():
    locid = row['locid']
    if locid in unique_raw_data:
        continue
    else:
        market_system_df.loc[index, 'new_account'] = 'x'

# %%
print('New Accounts:')
print('\n')
for x in market_system_df[market_system_df['new_account'] == 'x']['client'].unique():
    print(x)
# Out:
# New Accounts:
#
#
# The Office Bar & Grill (Sunnyvale/E Washington)
# Toll House Hotel (Los Gatos/S Santa Cruz)
# Hotel Mac Restaurant (Richmond/Washington)
# Agrodolce Osteria (Berkeley/Shattuck)
# The Beerded Bean (Salinas/S Main)
# Regal El Dorado Hills & IMAX (El Dorado Hills/Vine)
# Mezcalito Oaxacan (Rocklin/Pacific)
# Ramen One (San Jose/Saratoga)
# Roam Artisan Burgers (Oakland/Telegraph)
# Lark (San Francisco/18th)
# Cafe Europa (San Francisco/California)

# %% [markdown]
# # Independent Clean
#
# Accounts that want us to clean all their products, even if we do not service it. These accounts will be billed directly for their independent lines.
#
# * Pull list of IND accounts
# * Check for any lines that are marked DNB
